# %%
import pandas as pd
import cleaning as clean
from bs4 import BeautifulSoup
import json
import csv

# %% [markdown]
# ### In this file we will look up the information in the datasets, and clean and filter it for our interests

# %%
##input folder-> movies_data1 file
movies1=clean.open_csv()
# Out:
# Please, enter the folder where your cvs file is saved:
# input
# Please, enter the name for the cvs file you want to open without extension:
# movies_data1

# %%
movies1.head()
# Out:
#    Unnamed: 0  ID                           Title  Year  Age  IMDb  \
# 0           0   1                       Inception  2010  13+   8.8
# 1           1   2                      The Matrix  1999  18+   8.7
# 2           2   3          Avengers: Infinity War  2018  13+   8.5
# 3           3   4              Back to the Future  1985   7+   8.5
# 4           4   5  The Good, the Bad and the Ugly  1966  18+   8.8
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# 2             84%        1     0            0        0     0
# 3             96%        1     0            0        0     0
# 4             97%        1     0            1        0     0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime
# 0  United States,United Kingdom  English,Japanese,French    148.0
# 1                 United States                  English    136.0
# 2                 United States                  English    149.0
# 3                 United States                  English    116.0
# 4      Italy,Spain,West Germany                  Italian    161.0

# %%
movies1.shape
# Out:
# (16744, 17)

# %%
#Firsts of all, we clean white spaces in columns' names:
clean.rename_columns(movies1)

# %%
# UNnamed:0 is a kind of index that we don't neeed; we will drop that column. The same happens with ID
movies1['Unnamed:_0'].unique()
# Out:
# array([    0,     1,     2, ..., 16741, 16742, 16743])

# %%
##As Rotten_Tomatoes column has a 70% of null values, we will aslso drop that column
clean.rounding_value(movies1.Rotten_Tomatoes.isnull().sum()/movies1.shape[0])*100
# Out:
# 69.0

# %%
#As we see in the dataset description, movies have type zero (type 1 for TV series)
movies1=movies1[movies1['Type']==0]

# %%
movies1=clean.drop_columns(movies1,'Unnamed:_0','ID','Rotten_Tomatoes')

# %%
movies1.head()
# Out:
#                             Title  Year  Age  IMDb  Netflix  Hulu  \
# 0                       Inception  2010  13+   8.8        1     0
# 1                      The Matrix  1999  18+   8.7        1     0
# 2          Avengers: Infinity War  2018  13+   8.5        1     0
# 3              Back to the Future  1985   7+   8.5        1     0
# 4  The Good, the Bad and the Ugly  1966  18+   8.8        1     0
#
#    Prime_Video  Disney+  Type                       Directors  \
# 0            0        0     0               Christopher Nolan
# 1            0        0     0  Lana Wachowski,Lilly Wachowski
# 2            0        0     0         Anthony Russo,Joe Russo
# 3            0        0     0                 Robert Zemeckis
# 4            1        0     0                    Sergio Leone
#
#                              Genres                       Country  \
# 0  Action,Adventure,Sci-Fi,Thriller  United States,United Kingdom
# 1                     Action,Sci-Fi                 United States
# 2           Action,Adventure,Sci-Fi                 United States
# 3           Adventure,Comedy,Sci-Fi                 United States
# 4                           Western      Italy,Spain,West Germany
#
#                   Language  Runtime
# 0  English,Japanese,French    148.0
# 1                  English    136.0
# 2                  English    149.0
# 3                  English    116.0
# 4                  Italian    161.0

# %%
movies1.loc[movies1['Directors']=='Sergio Leone']
# Out:
#                              Title  Year  Age  IMDb  Netflix  Hulu  \
# 4   The Good, the Bad and the Ugly  1966  18+   8.8        1     0
# 15    Once Upon a Time in the West  1968  13+   8.5        1     0
#
#     Prime_Video  Disney+  Type     Directors   Genres  \
# 4             1        0     0  Sergio Leone  Western
# 15            1        0     0  Sergio Leone  Western
#
#                      Country                 Language  Runtime
# 4   Italy,Spain,West Germany                  Italian    161.0
# 15       Italy,United States  Italian,English,Spanish    165.0

# %%
movies1.loc[movies1['Country']=='Spain']
# Out:
#                                 Title  Year  Age  IMDb  Netflix  Hulu  \
# 35                              Klaus  2019   7+   8.2        1     0
# 69                The Invisible Guest  2016  18+   8.1        1     0
# 92                       The Platform  2019  18+   7.0        1     0
# 217                            Mirage  2018  18+   7.4        1     0
# 492    The Photographer of Mauthausen  2018  18+   6.7        1     0
# ...                               ...   ...  ...   ...      ...   ...
# 15294                       Hooked Up  2013  NaN   3.9        0     0
# 15579              Bunker: Project 12  2016  NaN   3.3        0     0
# 15771                Dragon Guardians  2013   7+   4.8        0     0
# 15863                       Belli Don  2018  NaN   NaN        0     0
# 15944                             Bye  2013  NaN   NaN        0     0
#
#        Prime_Video  Disney+  Type                            Directors  \
# 35               0        0     0  Sergio Pablos,Carlos Martínez López
# 69               0        0     0                          Oriol Paulo
# 92               0        0     0               Galder Gaztelu-Urrutia
# 217              1        0     0                          Oriol Paulo
# 492              0        0     0                        Mar Targarona
# ...            ...      ...   ...                                  ...
# 15294            1        0     0                        Pablo Larcuen
# 15579            1        0     0                         Jaime Falero
# 15771            1        0     0        Ángel Izquierdo,Ricardo Ramón
# 15863            1        0     0               Emilio Martínez Lázaro
# 15944            1        0     0                         Paco Cabezas
#
#                                      Genres Country                Language  \
# 35        Animation,Adventure,Comedy,Family   Spain           English,Saami
# 69                   Crime,Mystery,Thriller   Spain                 Spanish
# 92                   Horror,Sci-Fi,Thriller   Spain                 Spanish
# 217          Drama,Mystery,Romance,Thriller   Spain                 Spanish
# 492    Biography,Drama,History,Thriller,War   Spain          Spanish,German
# ...                                     ...     ...                     ...
# 15294                Comedy,Horror,Thriller   Spain                 English
# 15579      Action,Adventure,Sci-Fi,Thriller   Spain                 English
# 15771                             Animation   Spain                 Spanish
# 15863                        Comedy,Romance   Spain  Basque,Spanish,Catalan
# 15944                        Drama,Thriller   Spain                 Spanish
#
#        Runtime
# 35        96.0
# 69       106.0
# 92        94.0
# 217      128.0
# 492      110.0
# ...        ...
# 15294     78.0
# 15579     97.0
# 15771     73.0
# 15863     99.0
# 15944    111.0
#
# [115 rows x 14 columns]

# %%
# Our dataset is ready for analysis
clean.export_csv(movies1)
#movies1 dataset to src folder
# Out:
# Please, enter the name for the cvs file you want to exportmovies1
# 'movies1 has been exported to cvs file'

# %%
##input folder-> movies_data1 file
movies2=pd.read_csv('../input/movies_data2.csv',encoding='latin-1')

# %%
##as we can see, cast and crew columns are JSON format, so we must explode them to take out information
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
cast = json.loads(movies['cast'][0])

# %%
cast[80].keys()
# Out:
# dict_keys(['cast_id', 'character', 'credit_id', 'gender', 'id', 'name', 'order'])

# %%
crew = json.loads(movies['crew'][0])

# %%
crew[80].keys()
# Out:
# dict_keys(['credit_id', 'department', 'gender', 'id', 'job', 'name'])
